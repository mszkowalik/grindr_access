# %%
import os
from math import radians, cos, isnan
from dotenv import load_dotenv
from datetime import datetime
from copy import deepcopy
import numpy as np
import pandas as pd
from mongoengine import connect, NotUniqueError
from pymongo import errors
import pygeohash as gh
import localization as lx
from deepdiff import DeepDiff
from stalkr import generate_grid_points
from grindr_access.grindrUser import grindrUser
from db_models import scrapedProfileModel, profileModel, profileHistoryModel, aggregatedProfileModel, profileLocationModel

load_dotenv()

connect(
    # db=os.getenv('MONGO_DB'),
    db="grindr",
    host=os.getenv('MONGO_URL'),
    port=27017,
    username=os.getenv('MONGO_USR'),
    password=os.getenv('MONGO_PWD'),
    authentication_source="admin"
    )
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True, read_preference=Primary(), authsource='admin', uuidrepresentation=3, driver=DriverInfo(name='MongoEngine', version='0.28.2', platform=None))

# %%
user = grindrUser()
mail = os.getenv('GRINDR_MAIL')
password = os.getenv('GRINDR_PASS')
krk_lat = 50.059185
krk_lon = 19.937809

user.login(mail, password)

# %%
center_lat, center_lon = krk_lat, krk_lon # Equator and Prime Meridian
side_m = 10000 # 10 km side length
accuracy_m = 1000 # 1000m
points_per_side = int(side_m/accuracy_m) # Generate 100 points

grid_points = generate_grid_points(center_lat, center_lon, side_m, points_per_side,jitter_m=200)

# %%
scraped_profiles = {}
localization_data = {}
batch_timestamp = int(datetime.now().timestamp() * 1000)
i=0
for anchor_point in grid_points:
    created = int(datetime.now().timestamp() * 1000)
    anchor_gh = gh.encode(anchor_point[0], anchor_point[1],12)
    actual_anchor_point = list(gh.decode(anchor_gh))
    # Get the profiles for the current point from grindr API
    profile_list = user.getProfiles(actual_anchor_point[0], actual_anchor_point[1])
    print(f"{i}/{len(grid_points)}\t Anchor_point: {actual_anchor_point}\t Anchor_gh: {anchor_gh}")
    for response in profile_list['items']:
        response_profile = response['data']
        prof = {}
        # Filter out upsell banners or other non-profiles
        profile_types = ["PartialProfileV1", "FullProfileV1"]
        is_profile = any(element in response_profile.get('@type') for element in profile_types)
        has_distance = response_profile.get('distanceMeters') is not None
        if is_profile and has_distance:
            #fill all the fields obtained from request
            prof['profileId'] = response_profile['profileId']
            prof['created'] = created
            prof['anchor_lat'] =  actual_anchor_point[0] # Add the lat and lon of the anchor point
            prof['anchor_lon'] =  actual_anchor_point[1]
            prof['anchor_gh'] = anchor_gh
            prof['batch_timestamp'] = batch_timestamp
            prof['distance_from_anchor'] = response_profile['distanceMeters']
            # Save the profile to the database
            scraped_prof = scrapedProfileModel(**prof)
            scraped_prof.save()
            # store locally for further processing
            if scraped_profiles.get(scraped_prof.profileId) is None:
                scraped_profiles[scraped_prof.profileId] = []
                localization_data[scraped_prof.profileId] = []

            #rename the profileType field to avoid conflicts with mongoengine
            if response_profile.get('@type'):
                response_profile['profileType'] =  response_profile.pop('@type')
            keys_to_remove = ['upsellItemType', 'distanceMeters']
            for key in keys_to_remove:
                response_profile.pop(key, None)

            scraped_profiles[scraped_prof.profileId].append(deepcopy(response_profile))
            localization_data[scraped_prof.profileId].append(prof)
    i+=1
# Out:
# 95/100	 Anchor_point: [50.105363, 19.94695]	 Anchor_gh: u2yjjckuvsez
# 96/100	 Anchor_point: [50.103843, 19.961886]	 Anchor_gh: u2yjn1pu19jr
# 97/100	 Anchor_point: [50.10333, 19.977217]	 Anchor_gh: u2yjn94cncsz
# 98/100	 Anchor_point: [50.105123, 19.991785]	 Anchor_gh: u2yjncme6rgj
# 99/100	 Anchor_point: [50.102592, 20.007889]	 Anchor_gh: u2yjp2ckc857

# %%
for profileId, profiles in scraped_profiles.items():
    # iterate over all profiles and merge all the data by updating te output dict
    merged_profile_dict = profileModel().to_mongo().to_dict()

    for profile_dict in profiles:
        merged_profile_dict.update(profile_dict)

    profile = profileModel.objects(profileId=profileId).first()
    aggregated_profile = aggregatedProfileModel.objects(profileId=profileId).first()
    # if profile does not exist, create it
    if not profile:
        merged_profile_dict['created'] = batch_timestamp
        merged_profile_dict['updated'] = batch_timestamp
        profile = profileModel(**merged_profile_dict)

        aggregated_profile = aggregatedProfileModel(**merged_profile_dict)
        profile.save()
        aggregated_profile.save()

    current_profile_dict =  {}
    if profile:
        current_profile_dict = profile.to_mongo().to_dict()
    # those fielsd are not received from the API, so we need to remove them from the current profile
    keys_to_remove = ['_id','created', 'updated', 'last_lat', 'last_lon', 'cover_photo']

    for key in keys_to_remove:
        current_profile_dict.pop(key, None)

    # compare the current profile with the merged one
    diff = DeepDiff(current_profile_dict, merged_profile_dict, ignore_order=True, verbose_level=2).to_dict()
    # if there is a difference, update the profile
    if diff != {}:
        print("Profile has changed: ", profileId)
        print(diff)
        profileHistory = profileHistoryModel(profileId=profileId, timestamp=batch_timestamp, diff=diff)
        try:
            profileHistory.save()
        except (NotUniqueError, errors.DuplicateKeyError):
                print("A document with the same unique index already exists. Ignoring.")

        # update the profile
        merged_profile_dict['updated'] = batch_timestamp
        profile.update(**merged_profile_dict)
        #aggregate the profile history
        new_dict = deepcopy(current_profile_dict)
        new_dict.update(merged_profile_dict)
        new_dict['updated'] = batch_timestamp
        aggregated_profile.update(**new_dict)
# Out:
# Profile has changed:  506963836
# {'dictionary_item_added': {"root['created']": 1710373679709, "root['updated']": 1710373679709}}
# Profile has changed:  425268984
# {'values_changed': {"root['profileType']": {'new_value': 'CascadeItemData$FullProfileV1', 'old_value': 'CascadeItemData$PartialProfileV1'}}, 'iterable_item_added': {"root['photoMediaHashes'][1]": 'd34cbcf857f26da69b4f1d742a58c79377ddbc9a', "root['photoMediaHashes'][2]": '5f41fac36ce9d3a7d514087afa5af75c07964c3c', "root['photoMediaHashes'][3]": 'd7d04fb33f5f34f191698c3ce969eea6bf1d09d8'}}
# Profile has changed:  188456814
# {'dictionary_item_added': {"root['created']": 1710373679709, "root['updated']": 1710373679709}}
# Profile has changed:  607939503
# {'values_changed': {"root['lastOnline']": {'new_value': 1710373580000, 'old_value': 1710372640000}}}
# Profile has changed:  453366185
# {'dictionary_item_added': {"root['created']": 1710373679709, "root['updated']": 1710373679709}}
# Profile has changed:  602258836
# {'values_changed': {"root['lastOnline']": {'new_value': 1710373290000, 'old_value': 1710372820000}}}
# Profile has changed:  568052167
# {'values_changed': {"root['lastOnline']": {'new_value': 1710373660000, 'old_value': 1710370980000}}}
# Profile has changed:  599523582
# {'values_changed': {"root['lastOnline']": {'new_value': 1710373290000, 'old_value': 1710371790000}}}
# Profile has changed:  447259235
# {'values_changed': {"root['lastOnline']": {'new_value': 1710373590000, 'old_value': 1710372710000}}}
# Profile has changed:  613783196
# {'values_changed': {"root['lastOnline']": {'new_value': 1710373550000, 'old_value': 1710371610000}}}
# Profile has changed:  613063375
# {'values_changed': {"root['lastOnline']": {'new_value': 1710373740000, 'old_value': 1710372230000}}}
# Profile has changed:  389571204
# {'values_changed': {"root['lastOnline']": {'new_value': 1710373230000, 'old_value': 1710372820000}}}
# Profile has changed:  551487090
# {'values_changed': {"root['lastOnline']": {'new_value': 1710
# {'values_changed': {"root['lastOnline']": {'new_value': 1710373390000, 'old_value': 1710369660000}}}
# Profile has changed:  498386653
# {'values_changed': {"root['lastOnline']": {'new_value': 1710373090000, 'old_value': 1710372950000}}}
# Profile has changed:  260491487
# {'values_changed': {"root['lastOnline']": {'new_value': 1710373670000, 'old_value': 1710368710000}}}
# Profile has changed:  572112323
# {'values_changed': {"root['lastOnline']": {'new_value': 1710373750000, 'old_value': 1710372530000}}}
# Profile has changed:  250996854
# {'values_changed': {"root['lastOnline']": {'new_value': 1710373470000, 'old_value': 1710371240000}}}
# Profile has changed:  602872591
# {'values_changed': {"root['lastOnline']": {'new_value': 1710373580000, 'old_value': 1710372520000}}}
# Profile has changed:  562575285
# {'values_changed': {"root['lastOnline']": {'new_value': 1710373220000, 'old_value': 1710372670000}}}
# Profile has changed:  562284178
# {'dictionary_item_added': {"root['created']": 1710373679709, "root['updated']": 1710373679709}}
# Profile has changed:  608336259
# {'values_changed': {"root['lastOnline']": {'new_value': 1710373320000, 'old_value': 1710372180000}}}
# Profile has changed:  610022148
# {'dictionary_item_added': {"root['aboutMe']": 'Please guys show yourself -have a face pic- thanks ☺️ \nChoo choo 🚂\n\nI’m not here only for nice bodies, be interesting. Show me something special. Let me be in your universe for a while. ', "root['age']": 35, "root['heightCm']": 169, "root['weightGrams']": 69000, "root['relationshipStatus']": 1, "root['bodyType']": 5, "root['hivStatus']": 1, "root['lastTestedDate']": 1696118400000}, 'values_changed': {"root['lastOnline']": {'new_value': 1710373220000, 'old_value': 1710372980000}}, 'iterable_item_added': {"root['meetAt'][0]": 1, "root['meetAt'][1]": 2, "root['meetAt'][2]": 3, "root['meetAt'][3]": 4}}
# Profile has changed:  598436616
# {'dictionary_item_added': {"root['created']": 1710373679709, "root['updated']": 1710373679709}}
# Profile has changed:  595899042
# {'values_changed': {"root['lastOnline']": {'new_value': 1710373670000, 'old_value': 1710372830000}, "root['displayName']": {'new_value': 'chętny?', 'old_value': 'Lukaszcoszukasz'}, "root['aboutMe']": {'new_value': ' Napisz pv chętnie odp, nie wysyłam pierwszy zdj. Szukam na fun ja  chubby boy.', 'old_value': 'jestem tutaj nowy 🙄 napisz pv chętnie odp, szukam starszych panów ale nie ma dolnej granicy haha. chubby boy prawiczek który chciałby to zmienic😈'}}}
# Profile has changed:  431602913
# {'values_changed': {"root['lastOnline']": {'new_value': 1710373010000, 'old_value': 1710370410000}}}
# Profile has changed:  612800
# {'values_changed': {"root['lastOnline']": {'new_value': 1710373480000, 'old_value': 1710372770000}}}
# Profile has changed:  593266547
# {'dictionary_item_added': {"root['created']": 1710373679709, "root['updated']": 1710373679709}}
# Profile has changed:  180866324
# {'values_changed': {"root['lastOnline']": {'new_value': 1710373710000, 'old_value': 1710372860000}}}
# Profile has changed:  318554906
# {'dictionary_item_added': {"root['displayName']": '🇬🇧'}, 'values_changed': {"root['lastOnline']": {'new_value': 1710373010000, 'old_value': 1710372390000}}}
# Profile has changed:  223377067
# {'values_changed': {"root['lastOnline']": {'new_value': 1710373590000, 'old_value': 1710372810000}}}
# Profile has changed:  613217556
# {'values_changed': {"root['lastOnline']": {'new_value': 1710373670000, 'old_value': 1710372910000}}}
# Profile has changed:  604953269
# {'values_changed': {"root['lastOnline']": {'new_value': 1710373390000, 'old_value': 1710372950000}}}
# Profile has changed:  349344164
# {'dictionary_item_added': {"root['created']": 1710373679709, "root['updated']": 1710373679709}}
# Profile has changed:  28642133
# {'values_changed': {"root['lastOnline']": {'new_value': 1710373510000, 'old_value': 1710369290000}}, 'iterable_item_added': {"root['tribes'][0]": 3, "root['tribes'][1]": 5, "root['tribes'][2]": 10, "root['meetAt'][0]": 1, "root['meetAt'][1]": 2, "root['meetAt'][2]": 3, "root['genders'][0]": 4}}
# Profile has changed:  613756535
# {'values_changed': {"root['lastOnline']": {'new_value': 1710373180000, 'old_value': 1710372590000}}}
# Profile has changed:  322030697
# {'values_changed': {"root['lastOnline']": {'new_value': 1710373690000, 'old_value': 1710372880000}}}
# Profile has changed:  486885166
# {'values_changed': {"root['lastOnline']": {'new_value': 1710373140000, 'old_value': 1710372970000}}}
# Profile has changed:  457383991
# {'values_changed': {"root['lastOnline']": {'new_value': 1710373240000, 'old_value': 1710372530000}}}
# Profile has changed:  315741243
# {'values_changed': {"root['lastOnline']": {'new_value': 1710373760000, 'old_value': 1710371870000}}}
# Profile has changed:  415019418
# {'dictionary_item_added': {"root['created']": 1710373679709, "root['updated']": 1710373679709}}
# Profile has changed:  408053300
# {'values_changed': {"root['lastOnline']": {'new_value': 1710373570000, 'old_value': 1710372940000}}}
# Profile has changed:  335861517
# {'values_changed': {"root['lastOnline']": {'new_value': 1710
# {'values_changed': {"root['lastOnline']": {'new_value': 1710373610000, 'old_value': 1710372930000}}}
# Profile has changed:  613737697
# {'values_changed': {"root['profileType']": {'new_value': 'CascadeItemData$FullProfileV1', 'old_value': 'CascadeItemData$PartialProfileV1'}}, 'iterable_item_added': {"root['photoMediaHashes'][1]": 'ec3a0fc56cf83adcd6d7032851907526b42faa00'}}
# Profile has changed:  454305501
# {'dictionary_item_added': {"root['created']": 1710373679709, "root['updated']": 1710373679709}}
# Profile has changed:  416901504
# {'values_changed': {"root['lastOnline']": {'new_value': 1710373020000, 'old_value': 1710372360000}}}
# Profile has changed:  468027684
# {'values_changed': {"root['lastOnline']": {'new_value': 1710373710000, 'old_value': 1710372610000}}}
# Profile has changed:  512896707
# {'values_changed': {"root['lastOnline']": {'new_value': 1710373450000, 'old_value': 1710372610000}}}
# Profile has changed:  79078979
# {'dictionary_item_added': {"root['created']": 1710373679709, "root['updated']": 1710373679709}}
# Profile has changed:  612550120
# {'dictionary_item_added': {"root['created']": 1710373679709, "root['updated']": 1710373679709}}
# Profile has changed:  548772010
# {'values_changed': {"root['lastOnline']": {'new_value': 1710373560000, 'old_value': 1710372650000}, "root['profileType']": {'new_value': 'CascadeItemData$FullProfileV1', 'old_value': 'CascadeItemData$PartialProfileV1'}}, 'iterable_item_added': {"root['photoMediaHashes'][1]": '06f9f287ad7bf070f47dc50bdb44621ee595b5c5', "root['photoMediaHashes'][2]": '6829878403bb03247a696befb80059e4965fbcd6'}}
# Profile has changed:  364604712
# {'values_changed': {"root['lastOnline']": {'new_value': 1710373550000, 'old_value': 1710372910000}}}
# Profile has changed:  601682721
# {'values_changed': {"root['lastOnline']": {'new_value': 1710373600000, 'old_value': 1710372900000}}}
# Profile has changed:  613292941
# {'values_changed': {"root['lastOnline']": {'new_value': 1710373760000, 'old_value': 1710372210000}}}
# Profile has changed:  480452113
# {'values_changed': {"root['lastOnline']": {'new_value': 1710373640000, 'old_value': 1710372980000}}}
# Profile has changed:  173554099
# {'dictionary_item_added': {"root['created']": 1710373679709, "root['updated']": 1710373679709}}
# Profile has changed:  436395482
# {'dictionary_item_added': {"root['created']": 1710373679709, "root['updated']": 1710373679709}}

# %%
def select_indices(distances):
    # Convert distances to numpy array for efficient operations
    distances = np.array(distances)

    # Get the indices of the smallest 20 distances
    closest_indices = distances.argsort()[:20]
    return closest_indices

def localize(ref_points,distances)->list:
    P=lx.Project(mode='Earth1',solver='LSE')
    if any(isnan(distance) for distance in distances):
        return
    selected_indexes = select_indices(distances)
    if len(selected_indexes) < 3:
        return
    for i in selected_indexes:
        P.add_anchor(f'anchore_{i}',ref_points[i])
    t,label=P.add_target(ID=123)
    for i in selected_indexes:
        t.add_measure(f'anchore_{i}',distances[i])
    # with suppress_print():
    P.solve()

    return [t.loc.x, t.loc.y]

def localizeProfile(profiles, max_distance=1000):
    localizations = {}
    # Convert the list of dictionaries to a pandas DataFrame
    profiles_df = pd.DataFrame(profiles)
    profiles_df = profiles_df[profiles_df['distance_from_anchor'] <= max_distance]
    if profiles_df.empty:
        return localizations, None
    profile_id = profiles_df['profileId'].iloc[0]
    batch_timestamp = profiles_df['batch_timestamp'].iloc[0]
    localizedProfile = None
    if "distance_from_anchor" in profiles_df.columns:
        ref_points = [[lat, lon] for lat, lon in zip(profiles_df['anchor_lat'].tolist(), profiles_df['anchor_lon'].tolist())]
        distances = profiles_df['distance_from_anchor'].tolist()
        estimated_position = localize(ref_points,distances)
        estimated_gh = gh.encode(estimated_position[0], estimated_position[1],12) if estimated_position else ""
        localizations[profile_id] = {
            "estimated_position": estimated_position,
            "estimated_gh": estimated_gh,
            "batch_timestamp": batch_timestamp,
            "ref_points": ref_points,
            "distances": profiles_df['distance_from_anchor'].tolist()
        }
        if estimated_position:
            #sometimes not all fields are properly set in the request. This makes sure, that all data are available in database
            loc_prof = {
                "lat": estimated_position[0],
                "lon": estimated_position[1],
                "geoHash": estimated_gh,
                "profileId": profile_id,
                "timestamp": int(datetime.now().timestamp() * 1000),
                "batch_timestamp": batch_timestamp
            }
            localizedProfile = profileLocationModel(**loc_prof) # Create a new LocatedProfileModel instance


    return localizations, localizedProfile

# %%
#multilateration results, localized profiles. profileId is the key
ml_results = {}
# dict with localized profiles (LocationHistoryModel) . profileId is the key
localized_profiles = {}
# iterate over all profiles and localize them
for profileId, scraped_profileList in localization_data.items():
    print(f"Localizing profile {profileId}...")
    new_locations, loc_profile = localizeProfile(scraped_profileList, max_distance=2*accuracy_m)
    if loc_profile:
        localized_profiles[profileId] = loc_profile
        try:
            loc_profile.save()  # Attempt to save the new LocationHistoryModel profile
        except NotUniqueError:
            print("A document with the same unique index already exists. Ignoring.")
    ml_results.update(new_locations)
# Out:
# Localizing profile 506963836...
# LSE Geolocating...
# Localizing profile 425268984...
# Localizing profile 608689794...
# LSE Geolocating...
# Localizing profile 575764954...
# LSE Geolocating...
# Localizing profile 188456814...
# LSE Geolocating...
# Localizing profile 605626903...
# LSE Geolocating...
# Localizing profile 240203576...
# LSE Geolocating...
# Localizing profile 602890040...
# LSE Geolocating...
# Localizing profile 407024401...
# LSE Geolocating...
# Localizing profile 445430209...
# LSE Geolocating...
# Localizing profile 607939503...
# LSE Geolocating...
# Localizing profile 548323276...
# LSE Geolocating...
# Localizing profile 480798103...
# LSE Geolocating...
# Localizing profile 596512305...
# LSE Geolocating...
# Localizing profile 612282296...
# LSE Geolocating...
# Localizing profile 600362825...
# LSE Geolocating...
# Localizing profile 453366185...
# Localizing profile 175974448...
# LSE Geolocating...
# Localizing profile 602258836...
# LSE Geolocating...
# Localizing profile 478007265...
# LSE Geolocating...
# Localizing profile 425629687...
# LSE Geolocating...
# Localizing profile 206859865...
# LSE Geolocating...
# Localizing profile 568052167...
# LSE Geolocating...
# Localizing profile 599523582...
# LSE Geolocating...
# Localizing profile 266008859...
# LSE Geolocating...
# Localizing profile 506500773...
# Localizing profile 447259235...
# LSE Geolocating...
# Localizing profile 613783196...
# LSE Geolocating...
# Localizing profile 613063375...
# LSE Geolocating...
# Localizing profile 572020778...
# Localizing profile 200903708...
# LSE Geolocating...
# Localizing profile 380700791...
# LSE Geolocating...
# Localizing profile 389571204...
# LSE Geolocating...
# Localizing profile 493094845...
# LSE Geolocating...
# Localizing profile 446228206...
# LSE Geolocating...
# Localizing profile 551487090...
# LSE Geolocating...
# Localizing profile 613711654...
# LSE Geolocating...
# Localizing profile 613547431...
# LSE Geolocating...
# Localizing profile 315534740...
# LSE Geolocating...
# Localizing profile 590805004...
# LSE Geolocating...
# Localizing profile 61548567...
# LSE Geolocating...
# Localizing profile 555741439...
# LSE Geolocating...
# Localizing profile 603254443...
# Localizing profile 320646267...
# LSE Geolocating...
# Localizing profile 78906327...
# LSE Geolocating...
# Localizing profile 56805017...
# LSE Geolocating...
# Localizing profile 289452718...
# LSE Geolocating...
# Localizing profile 568726356...
# LSE Geolocating...
# Localizing profile 595080877...
# LSE Geolocating...
# Localizing profile 610214454...
# Localizing profile 551480948...
# LSE Geolocating...
# Localizing profile 370357204...
# LSE Geolocating...
# Localizing profile 398423005...
# LSE Geolocating...
# Localizing profile 613364181...
# LSE Geolocating...
# Localizing profile 56824962...
# LSE Geolocating...
# Localizing profile 593867770...
# LSE Geolocating...
# Localizing profile 454658612...
# LSE Geolocating...
# Localizing profile 336504308...
# LSE Geolocating...
# Localizing profile 408570353...
# LSE Geolocating...
# Localizing profile 580321114...
# LSE Geolocating...
# Localizing profile 416837199...
# LSE Geolocating...
# Localizing profile 489973956...
# LSE Geolocating...
# Localizing profile 120172571...
# LSE Geolocating...
# Localizing profile 376067658...
# LSE Geolocating...
# Localizing profile 27621641...
# LSE Geolocating...
# Localizing profile 580742190...
# LSE Geolocating...
# Localizing profile 515435388...
# Localizing profile 44692847...
# LSE Geolocating...
# Localizing profile 603726685...
# LSE Geolocating...
# Localizing profile 396187246...
# Localizing profile 434533178...
# LSE Geolocating...
# Localizing profile 609176830...
# LSE Geolocating...
# Localizing profile 602241618...
# LSE Geolocating...
# Localizing profile 560633875...
# LSE Geolocating...
# Localizing profile 572309456...
# LSE Geolocating...
# Localizing profile 403803025...
# Localizing profile 453025688...
# LSE Geolocating...
# Localizing profile 314383667...
# LSE Geolocating...
# Localizing profile 607217576...
# LSE Geolocating...
# Localizing profile 189257889...
# LSE Geolocating...
# Localizing profile 351783424...
# LSE Geolocating...
# Localizing profile 332616794...
# LSE Geolocating...
# Localizing profile 554841787...
# LSE Geolocating...
# Localizing profile 266385157...
# LSE Geolocating...
# Localizing profile 569593140...
# LSE Geolocating...
# Localizing profile 559654442...
# LSE Geolocating...
# Localizing profile 516272200...
# LSE Geolocating...
# Localizing profile 265358255...
# LSE Geolocating...
# Localizing profile 415661839...
# LSE Geolocating...
# Localizing profile 611769590...
# LSE Geolocating...
# Localizing profile 603484387...
# LSE Geolocating...
# Localizing profile 550492085...
# LSE Geolocating...
# Localizing profile 510502985...
# LSE Geolocating...
# Localizing profile 412006984...
# LSE Geolocating...
# Localizing profile 594188986...
# LSE Geolocating...
# Localizing profile 605186677...
# LSE Geolocating...
# Localizing profile 613257091...
# LSE Geolocating...
# Localizing profile 226778137...
# Localizing profile 613580275...
# LSE Geolocating...
# Localizing profile 598118527...
# LSE Geolocating...
# Localizing profile 446113687...
# LSE Geolocating...
# Localizing profile 598567574...
# LSE Geolocating...
# Localizing profile 462710818...
# LSE Geolocating...
# Localizing profile 602206334...
# LSE Geolocating...
# Localizing profile 362529238...
# LSE Geolocating...
# Localizing profile 547291604...
# Localizing profile 604824686...
# LSE Geolocating...
# Localizing profile 584057704...
# Localizing profile 510783624...
# Localizing profile 613585722...
# LSE Geolocating...
# Localizing profile 453748500...
# LSE Geolocating...
# Localizing profile 302693585...
# LSE Geolocating...
# Localizing profile 584616382...
# LSE Geolocating...
# Localizing profile 342872009...
# LSE Geolocating...
# Localizing profile 446362112...
# LSE Geolocating...
# Localizing profile 610497396...
# LSE Geolocating...
# Localizing profile 170384178...
# Localizing profile 613819492...
# LSE Geolocating...
# Localizing profile 613198760...
# LSE Geolocating...
# Localizing profile 242728196...
# LSE Geolocating...
# Localizing profile 587614702...
# LSE Geolocating...
# Localizing profile 418006391...
# LSE Geolocating...
# Localizing profile 596780677...
# LSE Geolocating...
# Localizing profile 600647567...
# LSE Geolocating...
# Localizing profile 529485014...
# LSE Geolocating...
# Localizing profile 605129696...
# LSE Geolocating...
# Localizing profile 270716780...
# LSE Geolocating...
# Localizing profile 610140815...
# LSE Geolocating...
# Localizing profile 613175351...
# LSE Geolocating...
# Localizing profile 489103536...
# LSE Geolocating...
# Localizing profile 221524178...
# LSE Geolocating...
# Localizing profile 555607302...
# LSE Geolocating...
# Localizing profile 376837962...
# LSE Geolocating...
# Localizing profile 390296001...
# LSE Geolocating...
# Localizing profile 317934736...
# LSE Geolocating...
# Localizing profile 495647109...
# LSE Geolocating...
# Localizing profile 607385301...
# LSE Geolocating...
# Localizing profile 613555665...
# LSE Geolocating...
# Localizing profile 598146275...
# LSE Geolocating...
# Localizing profile 86130375...
# LSE Geolocating...
# Localizing profile 287106616...
# LSE Geolocating...
# Localizing profile 36190858...
# LSE Geolocating...
# Localizing profile 541235016...
# LSE Geolocating...
# Localizing profile 573298847...
# LSE Geolocating...
# Localizing profile 594555981...
# LSE Geolocating...
# Localizing profile 595299694...
# LSE Geolocating...
# Localizing profile 488748639...
# LSE Geolocating...
# Localizing profile 596703438...
# LSE Geolocating...
# Localizing profile 302990308...
# LSE Geolocating...
# Localizing profile 540456501...
# LSE Geolocating...
# Localizing profile 418967775...
# LSE Geolocating...
# Localizing profile 150593509...
# LSE Geolocating...
# Localizing profile 588581492...
# LSE Geolocating...
# Localizing profile 612310405...
# LSE Geolocating...
# Localizing profile 572932922...
# LSE Geolocating...
# Localizing profile 569308079...
# LSE Geolocating...
# Localizing profile 163986966...
# LSE Geolocating...
# Localizing profile 547712907...
# LSE Geolocating...
# Localizing profile 197952585...
# LSE Geolocating...
# Localizing profile 480883881...
# LSE Geolocating...
# Localizing profile 395871957...
# LSE Geolocating...
# Localizing profile 162345056...
# LSE Geolocating...
# Localizing profile 307597448...
# LSE Geolocating...
# Localizing profile 404740643...
# LSE Geolocating...
# Localizing profile 611267826...
# LSE Geolocating...
# Localizing profile 597807372...
# LSE Geolocating...
# Localizing profile 498386653...
# LSE Geolocating...
# Localizing profile 70587610...
# LSE Geolocating...
# Localizing profile 409868694...
# LSE Geolocating...
# Localizing profile 260491487...
# LSE Geolocating...
# Localizing profile 604607178...
# LSE Geolocating...
# Localizing profile 508448742...
# LSE Geolocating...
# Localizing profile 572112323...
# LSE Geolocating...
# Localizing profile 250996854...
# LSE Geolocating...
# Localizing profile 267075608...
# LSE Geolocating...
# Localizing profile 1063698...
# LSE Geolocating...
# Localizing profile 602872591...
# LSE Geolocating...
# Localizing profile 562575285...
# LSE Geolocating...
# Localizing profile 428236869...
# LSE Geolocating...
# Localizing profile 472764108...
# LSE Geolocating...
# Localizing profile 562284178...
# LSE Geolocating...
# Localizing profile 590836533...
# LSE Geolocating...
# Localizing profile 489239637...
# LSE Geolocating...
# Localizing profile 583868757...
# LSE Geolocating...
# Localizing profile 477367381...
# LSE Geolocating...
# Localizing profile 608336259...
# LSE Geolocating...
# Localizing profile 609749940...
# LSE Geolocating...
# Localizing profile 613511066...
# LSE Geolocating...
# Localizing profile 610211055...
# LSE Geolocating...
# Localizing profile 600391989...
# LSE Geolocating...
# Localizing profile 610022148...
# LSE Geolocating...
# Localizing profile 421996691...
# LSE Geolocating...
# Localizing profile 442420996...
# LSE Geolocating...
# Localizing profile 343727336...
# LSE Geolocating...
# Localizing profile 33394163...
# LSE Geolocating...
# Localizing profile 608829237...
# LSE Geolocating...
# Localizing profile 494542803...
# LSE Geolocating...
# Localizing profile 604650895...
# LSE Geolocating...
# Localizing profile 311602873...
# LSE Geolocating...
# Localizing profile 543376184...
# LSE Geolocating...
# Localizing profile 609923019...
# LSE Geolocating...
# Localizing profile 461725870...
# LSE Geolocating...
# Localizing profile 598436616...
# LSE Geolocating...
# Localizing profile 558602938...
# LSE Geolocating...
# Localizing profile 595899042...
# LSE Geolocating...
# Localizing profile 509065356...
# LSE Geolocating...
# Localizing profile 420957912...
# LSE Geolocating...
# Localizing profile 473208641...
# LSE Geolocating...
# Localizing profile 41452312...
# LSE Geolocating...
# Localizing profile 36347590...
# LSE Geolocating...
# Localizing profile 431602913...
# LSE Geolocating...
# Localizing profile 612800...
# LSE Geolocating...
# Localizing profile 459947131...
# LSE Geolocating...
# Localizing profile 593266547...
# LSE Geolocating...
# Localizing profile 596969540...
# LSE Geolocating...
# Localizing profile 180866324...
# LSE Geolocating...
# Localizing profile 472341121...
# LSE Geolocating...
# Localizing profile 318554906...
# LSE Geolocating...
# Localizing profile 414762058...
# LSE Geolocating...
# Localizing profile 223377067...
# LSE Geolocating...
# Localizing profile 613217556...
# LSE Geolocating...
# Localizing profile 604953269...
# LSE Geolocating...
# Localizing profile 605791185...
# LSE Geolocating...
# Localizing profile 349344164...
# LSE Geolocating...
# Localizing profile 55230772...
# LSE Geolocating...
# Localizing profile 612692067...
# LSE Geolocating...
# Localizing profile 222445300...
# LSE Geolocating...
# Localizing profile 487589979...
# LSE Geolocating...
# Localizing profile 28642133...
# LSE Geolocating...
# Localizing profile 580310751...
# LSE Geolocating...
# Localizing profile 613756535...
# LSE Geolocating...
# Localizing profile 322030697...
# LSE Geolocating...
# Localizing profile 424334930...
# LSE Geolocating...
# Localizing profile 486885166...
# LSE Geolocating...
# Localizing profile 4490983...
# LSE Geolocating...
# Localizing profile 457383991...
# LSE Geolocating...
# Localizing profile 338984990...
# LSE Geolocating...
# Localizing profile 509219853...
# LSE Geolocating...
# Localizing profile 315741243...
# LSE Geolocating...
# Localizing profile 357095347...
# LSE Geolocating...
# Localizing profile 447077309...
# LSE Geolocating...
# Localizing profile 415019418...
# LSE Geolocating...
# Localizing profile 408053300...
# LSE Geolocating...
# Localizing profile 613410279...
# LSE Geolocating...
# Localizing profile 335861517...
# LSE Geolocating...
# Localizing profile 436234620...
# Localizing profile 220320855...
# LSE Geolocating...
# Localizing profile 605741666...
# LSE Geolocating...
# Localizing profile 613283551...
# LSE Geolocating...
# Localizing profile 451184743...
# LSE Geolocating...
# Localizing profile 596701085...
# LSE Geolocating...
# Localizing profile 489795154...
# LSE Geolocating...
# Localizing profile 463938779...
# LSE Geolocating...
# Localizing profile 384260159...
# LSE Geolocating...
# Localizing profile 494076990...
# LSE Geolocating...
# Localizing profile 341186461...
# LSE Geolocating...
# Localizing profile 608296784...
# LSE Geolocating...
# Localizing profile 613674386...
# LSE Geolocating...
# Localizing profile 609287734...
# LSE Geolocating...
# Localizing profile 226148682...
# LSE Geolocating...
# Localizing profile 438407450...
# LSE Geolocating...
# Localizing profile 500121860...
# LSE Geolocating...
# Localizing profile 550278234...
# LSE Geolocating...
# Localizing profile 591012831...
# LSE Geolocating...
# Localizing profile 613838367...
# LSE Geolocating...
# Localizing profile 562929986...
# LSE Geolocating...
# Localizing profile 613829721...
# LSE Geolocating...
# Localizing profile 599738314...
# LSE Geolocating...
# Localizing profile 579552086...
# LSE Geolocating...
# Localizing profile 234522722...
# LSE Geolocating...
# Localizing profile 602966602...
# LSE Geolocating...
# Localizing profile 503911244...
# LSE Geolocating...
# Localizing profile 612013029...
# Localizing profile 595416659...
# LSE Geolocating...
# Localizing profile 613572232...
# LSE Geolocating...
# Localizing profile 613838884...
# LSE Geolocating...
# Localizing profile 340027608...
# LSE Geolocating...
# Localizing profile 612802478...
# LSE Geolocating...
# Localizing profile 565385898...
# LSE Geolocating...
# Localizing profile 470321078...
# LSE Geolocating...
# Localizing profile 301157486...
# LSE Geolocating...
# Localizing profile 611415554...
# LSE Geolocating...
# Localizing profile 613710711...
# LSE Geolocating...
# Localizing profile 579927293...
# LSE Geolocating...
# Localizing profile 151117655...
# LSE Geolocating...
# Localizing profile 419300199...
# LSE Geolocating...
# Localizing profile 572847426...
# LSE Geolocating...
# Localizing profile 613748876...
# LSE Geolocating...
# Localizing profile 604878813...
# Localizing profile 613605446...
# LSE Geolocating...
# Localizing profile 472596135...
# LSE Geolocating...
# Localizing profile 394909929...
# LSE Geolocating...
# Localizing profile 360347425...
# LSE Geolocating...
# Localizing profile 609444573...
# Localizing profile 234883393...
# LSE Geolocating...
# Localizing profile 607717814...
# LSE Geolocating...
# Localizing profile 506986755...
# LSE Geolocating...
# Localizing profile 225964973...
# LSE Geolocating...
# Localizing profile 84313932...
# Localizing profile 478618240...
# LSE Geolocating...
# Localizing profile 174227639...
# LSE Geolocating...
# Localizing profile 424201528...
# LSE Geolocating...
# Localizing profile 596484784...
# LSE Geolocating...
# Localizing profile 414685154...
# LSE Geolocating...
# Localizing profile 612821893...
# LSE Geolocating...
# Localizing profile 132827599...
# LSE Geolocating...
# Localizing profile 542849597...
# LSE Geolocating...
# Localizing profile 249757760...
# LSE Geolocating...
# Localizing profile 30757929...
# LSE Geolocating...
# Localizing profile 421645404...
# LSE Geolocating...
# Localizing profile 584386706...
# LSE Geolocating...
# Localizing profile 555707735...
# LSE Geolocating...
# Localizing profile 591770006...
# LSE Geolocating...
# Localizing profile 593365761...
# LSE Geolocating...
# Localizing profile 48351133...
# LSE Geolocating...
# Localizing profile 219344210...
# LSE Geolocating...
# Localizing profile 613552248...
# LSE Geolocating...
# Localizing profile 339774952...
# LSE Geolocating...
# Localizing profile 580132414...
# LSE Geolocating...
# Localizing profile 335026374...
# LSE Geolocating...
# Localizing profile 477603744...
# LSE Geolocating...
# Localizing profile 581139603...
# LSE Geolocating...
# Localizing profile 184940207...
# LSE Geolocating...
# Localizing profile 606709136...
# LSE Geolocating...
# Localizing profile 461619053...
# LSE Geolocating...
# Localizing profile 243478313...
# LSE Geolocating...
# Localizing profile 91923327...
# LSE Geolocating...
# Localizing profile 592053442...
# LSE Geolocating...
# Localizing profile 308101480...
# LSE Geolocating...
# Localizing profile 545109433...
# LSE Geolocating...
# Localizing profile 571801249...
# LSE Geolocating...
# Localizing profile 608141217...
# LSE Geolocating...
# Localizing profile 569448181...
# Localizing profile 494534878...
# LSE Geolocating...
# Localizing profile 613564850...
# LSE Geolocating...
# Localizing profile 572496584...
# LSE Geolocating...
# Localizing profile 609801924...
# LSE Geolocating...
# Localizing profile 558243693...
# LSE Geolocating...
# Localizing profile 413551026...
# Localizing profile 329079770...
# LSE Geolocating...
# Localizing profile 574858146...
# LSE Geolocating...
# Localizing profile 612961848...
# LSE Geolocating...
# Localizing profile 457722607...
# LSE Geolocating...
# Localizing profile 33991250...
# LSE Geolocating...
# Localizing profile 511960887...
# LSE Geolocating...
# Localizing profile 612418729...
# LSE Geolocating...
# Localizing profile 598222049...
# LSE Geolocating...
# Localizing profile 612098963...
# LSE Geolocating...
# Localizing profile 312061381...
# LSE Geolocating...
# Localizing profile 432450737...
# LSE Geolocating...
# Localizing profile 571114226...
# LSE Geolocating...
# Localizing profile 149624999...
# LSE Geolocating...
# Localizing profile 68599893...
# LSE Geolocating...
# Localizing profile 530208320...
# LSE Geolocating...
# Localizing profile 466199990...
# LSE Geolocating...
# Localizing profile 270845995...
# LSE Geolocating...
# Localizing profile 613774821...
# LSE Geolocating...
# Localizing profile 446797534...
# LSE Geolocating...
# Localizing profile 579275069...
# LSE Geolocating...
# Localizing profile 428902855...
# LSE Geolocating...
# Localizing profile 493156582...
# LSE Geolocating...
# Localizing profile 29475849...
# LSE Geolocating...
# Localizing profile 277013228...
# LSE Geolocating...
# Localizing profile 63997902...
# LSE Geolocating...
# Localizing profile 484644765...
# Localizing profile 361710572...
# LSE Geolocating...
# Localizing profile 589302243...
# LSE Geolocating...
# Localizing profile 167525074...
# LSE Geolocating...
# Localizing profile 574086383...
# LSE Geolocating...
# Localizing profile 27340590...
# LSE Geolocating...
# Localizing profile 599447052...
# LSE Geolocating...
# Localizing profile 598026625...
# LSE Geolocating...
# Localizing profile 600283390...
# LSE Geolocating...
# Localizing profile 298940395...
# LSE Geolocating...
# Localizing profile 593073196...
# LSE Geolocating...
# Localizing profile 73654112...
# LSE Geolocating...
# Localizing profile 612693899...
# LSE Geolocating...
# Localizing profile 573444223...
# LSE Geolocating...
# Localizing profile 442839333...
# LSE Geolocating...
# Localizing profile 562175770...
# LSE Geolocating...
# Localizing profile 43580143...
# LSE Geolocating...
# Localizing profile 612849646...
# LSE Geolocating...
# Localizing profile 605451984...
# LSE Geolocating...
# Localizing profile 364387452...
# Localizing profile 109744051...
# LSE Geolocating...
# Localizing profile 268587623...
# LSE Geolocating...
# Localizing profile 415605942...
# LSE Geolocating...
# Localizing profile 569771550...
# LSE Geolocating...
# Localizing profile 608609356...
# LSE Geolocating...
# Localizing profile 595490102...
# LSE Geolocating...
# Localizing profile 251985144...
# LSE Geolocating...
# Localizing profile 589356817...
# LSE Geolocating...
# Localizing profile 613005969...
# LSE Geolocating...
# Localizing profile 472668749...
# LSE Geolocating...
# Localizing profile 609229189...
# LSE Geolocating...
# Localizing profile 418906258...
# LSE Geolocating...
# Localizing profile 610682389...
# LSE Geolocating...
# Localizing profile 31780311...
# LSE Geolocating...
# Localizing profile 508698506...
# LSE Geolocating...
# Localizing profile 612839260...
# LSE Geolocating...
# Localizing profile 177438817...
# LSE Geolocating...
# Localizing profile 613817380...
# LSE Geolocating...
# Localizing profile 597153337...
# LSE Geolocating...
# Localizing profile 251123566...
# LSE Geolocating...
# Localizing profile 598151630...
# LSE Geolocating...
# Localizing profile 606987350...
# LSE Geolocating...
# Localizing profile 31448557...
# LSE Geolocating...
# Localizing profile 448584326...
# LSE Geolocating...
# Localizing profile 257186031...
# LSE Geolocating...
# Localizing profile 602484222...
# LSE Geolocating...
# Localizing profile 243999242...
# LSE Geolocating...
# Localizing profile 188301328...
# LSE Geolocating...
# Localizing profile 416872028...
# LSE Geolocating...
# Localizing profile 261011673...
# LSE Geolocating...
# Localizing profile 64776001...
# LSE Geolocating...
# Localizing profile 428050847...
# LSE Geolocating...
# Localizing profile 598487282...
# LSE Geolocating...
# Localizing profile 573732834...
# LSE Geolocating...
# Localizing profile 550727963...
# LSE Geolocating...
# Localizing profile 585366875...
# LSE Geolocating...
# Localizing profile 606787303...
# LSE Geolocating...
# Localizing profile 353414027...
# LSE Geolocating...
# Localizing profile 553761376...
# LSE Geolocating...
# Localizing profile 482549525...
# LSE Geolocating...
# Localizing profile 183431506...
# LSE Geolocating...
# Localizing profile 176114806...
# LSE Geolocating...
# Localizing profile 574184432...
# LSE Geolocating...
# Localizing profile 42319075...
# LSE Geolocating...
# Localizing profile 131882790...
# LSE Geolocating...
# Localizing profile 596793979...
# LSE Geolocating...
# Localizing profile 348452906...
# LSE Geolocating...
# Localizing profile 610256501...
# LSE Geolocating...
# Localizing profile 224139278...
# LSE Geolocating...
# Localizing profile 613487629...
# LSE Geolocating...
# Localizing profile 323806040...
# LSE Geolocating...
# Localizing profile 605334374...
# LSE Geolocating...
# Localizing profile 609412582...
# LSE Geolocating...
# Localizing profile 611774484...
# LSE Geolocating...
# Localizing profile 73527512...
# LSE Geolocating...
# Localizing profile 385860680...
# LSE Geolocating...
# Localizing profile 601884472...
# LSE Geolocating...
# Localizing profile 459674684...
# LSE Geolocating...
# Localizing profile 612249586...
# LSE Geolocating...
# Localizing profile 362728891...
# LSE Geolocating...
# Localizing profile 437804388...
# Localizing profile 440766106...
# LSE Geolocating...
# Localizing profile 346736509...
# LSE Geolocating...
# Localizing profile 593492388...
# LSE Geolocating...
# Localizing profile 443166715...
# LSE Geolocating...
# Localizing profile 349509470...
# LSE Geolocating...
# Localizing profile 190060448...
# LSE Geolocating...
# Localizing profile 604112352...
# LSE Geolocating...
# Localizing profile 61435311...
# LSE Geolocating...
# Localizing profile 613616200...
# LSE Geolocating...
# Localizing profile 333837925...
# LSE Geolocating...
# Localizing profile 608196581...
# LSE Geolocating...
# Localizing profile 377750804...
# LSE Geolocating...
# Localizing profile 375675725...
# LSE Geolocating...
# Localizing profile 484168773...
# LSE Geolocating...
# Localizing profile 490009452...
# LSE Geolocating...
# Localizing profile 585724218...
# LSE Geolocating...
# Localizing profile 601432986...
# LSE Geolocating...
# Localizing profile 613796590...
# LSE Geolocating...
# Localizing profile 266738176...
# LSE Geolocating...
# Localizing profile 359185864...
# LSE Geolocating...
# Localizing profile 607796038...
# LSE Geolocating...
# Localizing profile 591555525...
# LSE Geolocating...
# Localizing profile 568473382...
# LSE Geolocating...
# Localizing profile 493836519...
# LSE Geolocating...
# Localizing profile 338100244...
# LSE Geolocating...
# Localizing profile 576493175...
# Localizing profile 444457082...
# LSE Geolocating...
# Localizing profile 545483112...
# LSE Geolocating...
# Localizing profile 568573606...
# LSE Geolocating...
# Localizing profile 610998690...
# LSE Geolocating...
# Localizing profile 613476568...
# LSE Geolocating...
# Localizing profile 580481883...
# LSE Geolocating...
# Localizing profile 612525566...
# LSE Geolocating...
# Localizing profile 593647849...
# LSE Geolocating...
# Localizing profile 607390696...
# LSE Geolocating...
# Localizing profile 592857749...
# LSE Geolocating...
# Localizing profile 325084842...
# LSE Geolocating...
# Localizing profile 612544885...
# LSE Geolocating...
# Localizing profile 443809755...
# LSE Geolocating...
# Localizing profile 470583721...
# LSE Geolocating...
# Localizing profile 504292563...
# LSE Geolocating...
# Localizing profile 504303855...
# LSE Geolocating...
# Localizing profile 603518656...
# LSE Geolocating...
# Localizing profile 71566289...
# LSE Geolocating...
# Localizing profile 230272476...
# LSE Geolocating...
# Localizing profile 516761921...
# Localizing profile 579380192...
# Localizing profile 610256783...
# Localizing profile 576575584...
# LSE Geolocating...
# Localizing profile 264356092...
# Localizing profile 566485024...
# LSE Geolocating...
# Localizing profile 475102798...
# LSE Geolocating...
# Localizing profile 607104507...
# Localizing profile 550270363...
# LSE Geolocating...
# Localizing profile 573959655...
# LSE Geolocating...
# Localizing profile 399901849...
# LSE Geolocating...
# Localizing profile 567725398...
# Localizing profile 613759808...
# LSE Geolocating...
# Localizing profile 608187176...
# LSE Geolocating...
# Localizing profile 611543939...
# LSE Geolocating...
# Localizing profile 145676438...
# Localizing profile 575542253...
# Localizing profile 88446099...
# LSE Geolocating...
# Localizing profile 613841493...
# LSE Geolocating...
# Localizing profile 556770478...
# LSE Geolocating...
# Localizing profile 591100858...
# LSE Geolocating...
# Localizing profile 321846341...
# Localizing profile 316907946...
# LSE Geolocating...
# Localizing profile 370416747...
# Localizing profile 567516970...
# LSE Geolocating...
# Localizing profile 613266392...
# LSE Geolocating...
# Localizing profile 383979260...
# LSE Geolocating...
# Localizing profile 252224011...
# Localizing profile 560591568...
# Localizing profile 337432061...
# LSE Geolocating...
# Localizing profile 600323859...
# Localizing profile 553214662...
# LSE Geolocating...
# Localizing profile 559363733...
# LSE Geolocating...
# Localizing profile 583862038...
# LSE Geolocating...
# Localizing profile 571632819...
# LSE Geolocating...
# Localizing profile 613760680...
# Localizing profile 22679968...
# Localizing profile 599713546...
# LSE Geolocating...
# Localizing profile 267036485...
# LSE Geolocating...
# Localizing profile 574146798...
# LSE Geolocating...
# Localizing profile 414849208...
# LSE Geolocating...
# Localizing profile 295899641...
# Localizing profile 161360211...
# Localizing profile 369129673...
# LSE Geolocating...
# Localizing profile 583870458...
# Localizing profile 285619038...
# LSE Geolocating...
# Localizing profile 263822702...
# LSE Geolocating...
# Localizing profile 582187296...
# LSE Geolocating...
# Localizing profile 56977351...
# LSE Geolocating...
# Localizing profile 49029456...
# LSE Geolocating...
# Localizing profile 544324998...
# Localizing profile 305706347...
# Localizing profile 529521137...
# Localizing profile 517173942...
# LSE Geolocating...
# Localizing profile 432700277...
# LSE Geolocating...
# Localizing profile 610380950...
# LSE Geolocating...
# Localizing profile 455400676...
# LSE Geolocating...
# Localizing profile 502799352...
# LSE Geolocating...
# Localizing profile 165347347...
# LSE Geolocating...
# Localizing profile 346568591...
# LSE Geolocating...
# Localizing profile 375743996...
# LSE Geolocating...
# Localizing profile 603971098...
# Localizing profile 613561469...
# LSE Geolocating...
# Localizing profile 613838256...
# LSE Geolocating...
# Localizing profile 565115842...
# Localizing profile 458345156...
# LSE Geolocating...
# Localizing profile 601424935...
# LSE Geolocating...
# Localizing profile 606679180...
# LSE Geolocating...
# Localizing profile 338078599...
# Localizing profile 613506384...
# Localizing profile 585329401...
# LSE Geolocating...
# Localizing profile 599036136...
# LSE Geolocating...
# Localizing profile 515296489...
# LSE Geolocating...
# Localizing profile 514544827...
# LSE Geolocating...
# Localizing profile 458460116...
# LSE Geolocating...
# Localizing profile 606359706...
# LSE Geolocating...
# Localizing profile 599284471...
# LSE Geolocating...
# Localizing profile 613808518...
# LSE Geolocating...
# Localizing profile 492892077...
# LSE Geolocating...
# Localizing profile 597122349...
# LSE Geolocating...
# Localizing profile 153576196...
# LSE Geolocating...
# Localizing profile 365063124...
# LSE Geolocating...
# Localizing profile 409701980...
# LSE Geolocating...
# Localizing profile 586694289...
# Localizing profile 540923659...
# LSE Geolocating...
# Localizing profile 606307373...
# LSE Geolocating...
# Localizing profile 543606877...
# LSE Geolocating...
# Localizing profile 335214350...
# LSE Geolocating...
# Localizing profile 602088064...
# LSE Geolocating...
# Localizing profile 468724853...
# LSE Geolocating...
# Localizing profile 613060841...
# LSE Geolocating...
# Localizing profile 333283827...
# LSE Geolocating...
# Localizing profile 353005779...
# LSE Geolocating...
# Localizing profile 583589904...
# LSE Geolocating...
# Localizing profile 394388614...
# Localizing profile 498851985...
# LSE Geolocating...
# Localizing profile 549595092...
# LSE Geolocating...
# Localizing profile 597137253...
# LSE Geolocating...
# Localizing profile 601057918...
# LSE Geolocating...
# Localizing profile 501616279...
# LSE Geolocating...
# Localizing profile 590481104...
# LSE Geolocating...
# Localizing profile 594357903...
# LSE Geolocating...
# Localizing profile 611724748...
# LSE Geolocating...
# Localizing profile 492189587...
# LSE Geolocating...
# Localizing profile 609246751...
# LSE Geolocating...
# Localizing profile 152354235...
# LSE Geolocating...
# Localizing profile 88209559...
# LSE Geolocating...
# Localizing profile 375754624...
# LSE Geolocating...
# Localizing profile 600661835...
# LSE Geolocating...
# Localizing profile 601684178...
# LSE Geolocating...
# Localizing profile 478714215...
# LSE Geolocating...
# Localizing profile 561730623...
# LSE Geolocating...
# Localizing profile 489845737...
# LSE Geolocating...
# Localizing profile 498185649...
# LSE Geolocating...
# Localizing profile 126168063...
# LSE Geolocating...
# Localizing profile 583792571...
# LSE Geolocating...
# Localizing profile 560361950...
# LSE Geolocating...
# Localizing profile 187017629...
# LSE Geolocating...
# Localizing profile 319116601...
# LSE Geolocating...
# Localizing profile 258848429...
# LSE Geolocating...
# Localizing profile 48539568...
# LSE Geolocating...
# Localizing profile 61871727...
# LSE Geolocating...
# Localizing profile 494559052...
# LSE Geolocating...
# Localizing profile 420616981...
# LSE Geolocating...
# Localizing profile 530235889...
# LSE Geolocating...
# Localizing profile 171062527...
# LSE Geolocating...
# Localizing profile 507550711...
# LSE Geolocating...
# Localizing profile 428741557...
# LSE Geolocating...
# Localizing profile 450797234...
# LSE Geolocating...
# Localizing profile 552710367...
# LSE Geolocating...
# Localizing profile 224114836...
# LSE Geolocating...
# Localizing profile 508202824...
# LSE Geolocating...
# Localizing profile 608165948...
# LSE Geolocating...
# Localizing profile 606348715...
# LSE Geolocating...
# Localizing profile 566491869...
# LSE Geolocating...
# Localizing profile 406532316...
# LSE Geolocating...
# Localizing profile 599866848...
# LSE Geolocating...
# Localizing profile 605682183...
# LSE Geolocating...
# Localizing profile 607383907...
# LSE Geolocating...
# Localizing profile 454196615...
# LSE Geolocating...
# Localizing profile 187886184...
# LSE Geolocating...
# Localizing profile 83672502...
# LSE Geolocating...
# Localizing profile 508829906...
# LSE Geolocating...
# Localizing profile 496864586...
# LSE Geolocating...
# Localizing profile 241672990...
# LSE Geolocating...
# Localizing profile 554218922...
# LSE Geolocating...
# Localizing profile 594439928...
# LSE Geolocating...
# Localizing profile 598733436...
# LSE Geolocating...
# Localizing profile 444458862...
# LSE Geolocating...
# Localizing profile 596296592...
# LSE Geolocating...
# Localizing profile 603265144...
# LSE Geolocating...
# Localizing profile 276916903...
# LSE Geolocating...
# Localizing profile 81369546...
# LSE Geolocating...
# Localizing profile 76540728...
# LSE Geolocating...
# Localizing profile 555613947...
# LSE Geolocating...
# Localizing profile 486298518...
# LSE Geolocating...
# Localizing profile 385809894...
# LSE Geolocating...
# Localizing profile 613069488...
# LSE Geolocating...
# Localizing profile 543645528...
# LSE Geolocating...
# Localizing profile 612121463...
# LSE Geolocating...
# Localizing profile 438457926...
# LSE Geolocating...
# Localizing profile 594863952...
# LSE Geolocating...
# Localizing profile 470403413...
# LSE Geolocating...
# Localizing profile 176733588...
# LSE Geolocating...
# Localizing profile 413263299...
# LSE Geolocating...
# Localizing profile 583264430...
# LSE Geolocating...
# Localizing profile 281611243...
# LSE Geolocating...
# Localizing profile 613767341...
# LSE Geolocating...
# Localizing profile 597635624...
# LSE Geolocating...
# Localizing profile 466367834...
# LSE Geolocating...
# Localizing profile 574475235...
# LSE Geolocating...
# Localizing profile 399218668...
# LSE Geolocating...
# Localizing profile 595759987...
# LSE Geolocating...
# Localizing profile 569768156...
# LSE Geolocating...
# Localizing profile 551430259...
# LSE Geolocating...
# Localizing profile 567536831...
# LSE Geolocating...
# Localizing profile 491667226...
# LSE Geolocating...
# Localizing profile 184143800...
# LSE Geolocating...
# Localizing profile 370905626...
# LSE Geolocating...
# Localizing profile 467772785...
# LSE Geolocating...
# Localizing profile 324208597...
# LSE Geolocating...
# Localizing profile 437537673...
# LSE Geolocating...
# Localizing profile 613737697...
# LSE Geolocating...
# Localizing profile 587633398...
# LSE Geolocating...
# Localizing profile 317298462...
# LSE Geolocating...
# Localizing profile 612684007...
# Localizing profile 389387912...
# LSE Geolocating...
# Localizing profile 454305501...
# LSE Geolocating...
# Localizing profile 446363097...
# Localizing profile 395240696...
# LSE Geolocating...
# Localizing profile 416901504...
# LSE Geolocating...
# Localizing profile 394290152...
# LSE Geolocating...
# Localizing profile 468027684...
# LSE Geolocating...
# Localizing profile 512896707...
# LSE Geolocating...
# Localizing profile 79078979...
# LSE Geolocating...
# Localizing profile 433138596...
# LSE Geolocating...
# Localizing profile 612550120...
# LSE Geolocating...
# Localizing profile 548772010...
# LSE Geolocating...
# Localizing profile 411563393...
# LSE Geolocating...
# Localizing profile 469254383...
# LSE Geolocating...
# Localizing profile 364604712...
# LSE Geolocating...
# Localizing profile 529293156...
# LSE Geolocating...
# Localizing profile 593191688...
# LSE Geolocating...
# Localizing profile 486487978...
# LSE Geolocating...
# Localizing profile 601682721...
# LSE Geolocating...
# Localizing profile 613292941...
# Localizing profile 562442632...
# LSE Geolocating...
# Localizing profile 480452113...
# LSE Geolocating...
# Localizing profile 406851594...
# LSE Geolocating...
# Localizing profile 173554099...
# LSE Geolocating...
# Localizing profile 436395482...
